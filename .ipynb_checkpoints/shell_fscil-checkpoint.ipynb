# %%
apprs = ['eeil', 'ewc', 'icarl', 'lwf']

# %%
# !python train.py --approach eeil

# !python train.py --approach ewc

# !python train.py --approach icarl

# !python train.py --approach lwf
# Out:
# ...
# Arguments =
# 	approach: eeil
# 	batch_size: 128
# 	clipping: 10000
# 	datasets: ['fs_sei']
# 	eval_on_train: False
# 	exp_name: None
# 	fix_bn: False
# 	gpu: 0
# 	keep_existing_head: False
# 	last_layer_analysis: True
# 	log: ['disk']
# 	lr: 0.005
# 	lr_factor: 3
# 	lr_min: 0.0001
# 	lr_patience: 5
# 	momentum: 0.0
# 	multi_softmax: False
# 	nc_first_task: None
# 	nepochs: 2
# 	network: conformer
# 	no_cudnn_deterministic: False
# 	num_tasks: 5
# 	num_workers: 0
# 	pin_memory: False
# 	pretrained: False
# 	results_path: ./results
# 	save_models: True
# 	schedule_step: [110, 130]
# 	seed: 0
# 	stop_at_task: 0
# 	topk: 3
# 	use_valid_only: False
# 	warmup_lr_factor: 1.0
# 	warmup_nepochs: 0
# 	weight_decay: 0.0
# ...
# Extra Arguments =
# []
# ...
# Approach Arguments =
# 	T: 2.0
# 	lamb: 1.0
# 	lr_finetuning_factor: 0.01
# 	nepochs_finetuning: 1
# 	noise_grad: False
# ...
# Examplars Arguments =
# 	exemplar_selection: herding
# 	num_exemplars: 0
# 	num_exemplars_per_class: 20
# ...
